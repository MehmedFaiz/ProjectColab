# %% [markdown]
# <a href="https://colab.research.google.com/github/MehmedFaiz/ProjectColab/blob/main/belajarpandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f30d32c9-f79a-454c-bbb0-a0ef774187fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f30d32c9-f79a-454c-bbb0-a0ef774187fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_path = "sales_data.csv"
df = pd.read_csv(file_path)
print(df.head())
print(df.info())
print(df.describe())
# Out:
#       tanggal      produk    kategori  jumlah_terjual  harga_satuan  \
# 0  2024-01-01      Laptop  Elektronik               5      15000000
# 1  2024-01-02  Smartphone  Elektronik              10       5000000
# 2  2024-01-03   Headphone   Aksesoris              15        500000
# 3  2024-01-04      TV LED  Elektronik               3       8000000
# 4  2024-01-05      Kulkas  Elektronik               2       6000000
#
#    total_penjualan diskon    lokasi
# 0         75000000     5%   Jakarta
# 1         50000000    10%   Bandung
# 2          7500000     5%  Surabaya
# 3         24000000     7%     Medan
# 4         12000000     7%  Makassar
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tanggal          7 non-null      object
#  1   produk           7 non-null      object
#  2   kategori         7 non-null      object
# ...

# %% [markdown]
# After uploading, the file will be available in the Colab environment. You can then use its name directly, like in your original code: `file_path = "sales_data.csv"`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['tanggal'] = pd.to_datetime(df['tanggal'])

df_daily = df.groupby(df['tanggal'].dt.date)['total_penjualan'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x=df_daily['tanggal'].astype(str), y=df_daily['total_penjualan'], marker='o')
plt.xticks(rotation=45)
plt.xlabel("Tanggal")
plt.ylabel("Total Penjualan")
plt.title("Tren Penjualan Harian")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Korelasi antar variabel dalam dataset penjualan")
plt.show()
