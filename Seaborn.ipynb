# %% [markdown]
# <a href="https://colab.research.google.com/github/MehmedFaiz/ProjectColab/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset('tips')

sns.scatterplot(x='total_bill', y='tip', data=data)
plt.title('Scatterplot of Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
data = sns.load_dataset("iris")

sns.histplot(data["sepal_length"], bins=20, kde=True)
plt.title("Distribusi panjang Sepal dan Dataset Iris")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 6))
numeric_data = data.drop(columns=['species'])
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Heatmap Korelasi Dataset Iris")
plt.show()
